# %%
import os
import autolingua
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
sns.set_palette("tab10")

# %%
table_path = os.path.join(autolingua.__path__[0], '..', 'data', 'agg_analysis.csv')
df = pd.read_csv(table_path, sep=';', index_col=0)

# %%
df
# Out:
#                                                Estudio  Longitud listas  \
# 1.0                                             Genero        11.698759
# 2.0                                             Genero        12.812851
# 3.0                                             Genero        16.527273
# 1.0                                    Nivel educativo        10.664091
# 2.0                                    Nivel educativo        12.255455
# ..                                                 ...              ...
# 2.0  Centro de interés 8 - Bachiller - CentroPublic...        10.120000
# 1.0  Centro de interés 9 - Bachiller - CentroPublic...        11.380000
# 2.0  Centro de interés 9 - Bachiller - CentroPublic...        13.280000
# 1.0  Centro de interés 10 - Bachiller - CentroPubli...        12.800000
# 2.0  Centro de interés 10 - Bachiller - CentroPubli...        13.690000
#
#      Vocabulario único  Población
# 1.0               5987        271
# ...

# %%
# Select the rows with df['Estudio'] that contain 'Centro de interés'
df_ci = df[df['Estudio'].str.contains(f' - NivelEducativo')]

# Cast the index to int and set it as a new column 'legend'
df_ci['legend'] = df_ci.index.astype(int)

# Set a new column 'x' with the value between 'Centro de interés ' and ' - NivelEducativo' of column 'Estudio'
df_ci['x'] = df_ci['Estudio'].apply(lambda x: int(x.split('Centro de interés ')[1].split(' - NivelEducativo')[0]))
# Out:
# /tmp/ipykernel_12095/237062408.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ci['legend'] = df_ci.index.astype(int)
# /tmp/ipykernel_12095/237062408.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ci['x'] = df_ci['Estudio'].apply(lambda x: int(x.split('Centro de interés ')[1].split(' - NivelEducativo')[0]))

# %%
# Check everything is ok
df_ci
# Out:
#                                    Estudio  Longitud listas  \
# 1.0   Centro de interés 0 - NivelEducativo           13.520
# 2.0   Centro de interés 0 - NivelEducativo           14.690
# 3.0   Centro de interés 0 - NivelEducativo           16.635
# 1.0   Centro de interés 1 - NivelEducativo           11.265
# 2.0   Centro de interés 1 - NivelEducativo           12.605
# 3.0   Centro de interés 1 - NivelEducativo           13.860
# 1.0   Centro de interés 2 - NivelEducativo           10.180
# 2.0   Centro de interés 2 - NivelEducativo           12.570
# 3.0   Centro de interés 2 - NivelEducativo           13.915
# 1.0   Centro de interés 3 - NivelEducativo           13.380
# 2.0   Centro de interés 3 - NivelEducativo           14.390
# 3.0   Centro de interés 3 - NivelEducativo           15.840
# 1.0   Centro de interés 4 - NivelEducativo            9.490
# 2.0   Centro de interés 4 - NivelEducativo           11.125
# 3.0   Centro de interés 4 - NivelEducativo           13.070
# ...

# %%
# Draw a nested barplot by species and sex
g = sns.catplot(
    data=df_ci, kind="bar",
    x="x", y="Longitud listas", hue="legend", alpha=1, height=5, aspect=2.5,
    palette='binary'
)
g.despine(left=True)
g.set_axis_labels('Centro de interés', 'Longitud de las listas')
g.legend.set_title('Nivel educativo')

# Increase the gap between the legend and the plot
plt.subplots_adjust(right=0.89)
# Out:
# /home/breaststroker/anaconda3/envs/autolingua/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Draw a nested barplot by species and sex
g = sns.catplot(
    data=df_ci, kind="bar",
    x="x", y="Vocabulario único", hue="legend", alpha=1, height=5, aspect=2.5,
    palette='binary'
)
g.despine(left=True)
g.set_axis_labels('Centro de interés', 'Número de palabras únicas')
g.legend.set_title('Nivel educativo')

# Increase the gap between the legend and the plot
plt.subplots_adjust(right=0.89)
# Out:
# /home/breaststroker/anaconda3/envs/autolingua/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
